# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from env import host, user, password
import acquire
import prepare
import explore
import report_wdate
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
#  13  streaming_tv              7043 non-null   object
#  14  streaming_movies          7043 non-null   object
#  15  contract_type_id          7043 non-null   int64
#  16  paperless_billing         7043 non-null   object
#  17  payment_type_id           7043 non-null   int64
#  18  monthly_charges           7043 non-null   float64
#  19  total_charges             7043 non-null   object
#  20  churn                     7043 non-null   object
#  21  signup_date               7043 non-null   object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 1.2+ MB
# this data frame has 7043 rows and 22 columns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
#  13  streaming_tv              7043 non-null   object
#  14  streaming_movies          7043 non-null   object
#  15  contract_type_id          7043 non-null   int64
#  16  paperless_billing         7043 non-null   object
#  17  payment_type_id           7043 non-null   int64
#  18  monthly_charges           7043 non-null   float64
#  19  total_charges             7043 non-null   object
#  20  churn                     7043 non-null   object
#  21  signup_date               7043 non-null   object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 1.2+ MB
# None
#
#        senior_citizen       tenure  internet_service_type_id  \
# count     7043.000000  7043.000000               7043.000000
# mean         0.162147    32.371149                  1.872923
# std          0.368612    24.559481                  0.737796
# min          0.000000     0.000000                  1.000000
# 25%          0.000000     9.000000                  1.000000
# 50%          0.000000    29.000000                  2.000000
# 75%          0.000000    55.000000                  2.000000
# max          1.000000    72.000000                  3.000000
#
#        contract_type_id  payment_type_id  monthly_charges
# count       7043.000000      7043.000000      7043.000000
# mean           1.690473         2.315633        64.761692
# std            0.833755         1.148907        30.090047
# min            1.000000         1.000000        18.250000
# 25%            1.000000         1.000000        35.500000
# 50%            1.000000         2.000000        70.350000
# 75%            2.000000         3.000000        89.850000
# max            3.000000         4.000000       118.750000
#
#                   count unique                  top  freq
# customer_id        7043   7043           0002-ORFBO     1
# gender             7043      2                 Male  3555
# partner            7043      2                   No  3641
# dependents         7043      2                   No  4933
# phone_service      7043      2                  Yes  6361
# multiple_lines     7043      3                   No  3390
# online_security    7043      3                   No  3498
# online_backup      7043      3                   No  3088
# device_protection  7043      3                   No  3095
# tech_support       7043      3                   No  3473
# streaming_tv       7043      3                   No  2810
# streaming_movies   7043      3                   No  2785
# paperless_billing  7043      2                  Yes  4171
# total_charges      7043   6531                         11
# churn              7043      2                   No  5174
# signup_date        7043     73  2021-12-21 18:07:34   613
#
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service_type_id',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract_type_id',
#        'paperless_billing', 'payment_type_id', 'monthly_charges',
#        'total_charges', 'churn', 'signup_date'],
#       dtype='object')
# ended of initial report

# %% [markdown]
# # inital data retrieval and analysis

# %%
telco_df=acquire.get_telco_data()

# %%
telco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 7043 non-null   object
#  1   internet_service_type_id    7043 non-null   int64
#  2   contract_type_id            7043 non-null   int64
#  3   gender                      7043 non-null   object
#  4   senior_citizen              7043 non-null   int64
#  5   partner                     7043 non-null   object
#  6   dependents                  7043 non-null   object
#  7   tenure                      7043 non-null   int64
#  8   phone_service               7043 non-null   object
#  9   multiple_lines              7043 non-null   object
#  10  online_security             7043 non-null   object
#  11  online_backup               7043 non-null   object
#  12  device_protection           7043 non-null   object
#  13  tech_support                7043 non-null   object
#  14  streaming_tv                7043 non-null   object
#  15  streaming_movies            7043 non-null   object
#  16  paperless_billing           7043 non-null   object
#  17  payment_type_id             7043 non-null   int64
#  18  monthly_charges             7043 non-null   float64
#  19  total_charges               7043 non-null   object
#  20  churn                       7043 non-null   object
#  21  contract_type               7043 non-null   object
#  22  internet_service_type       7043 non-null   object
#  23  phone_service.1             7043 non-null   object
#  24  multiple_lines.1            7043 non-null   object
#  25  internet_service_type_id.1  7043 non-null   int64
#  26  online_security.1           7043 non-null   object
#  27  online_backup.1             7043 non-null   object
#  28  device_protection.1         7043 non-null   object
#  29  tech_support.1              7043 non-null   object
#  30  streaming_tv.1              7043 non-null   object
#  31  streaming_movies.1          7043 non-null   object
#  32  contract_type_id.1          7043 non-null   int64
#  33  paperless_billing.1         7043 non-null   object
#  34  payment_type_id.1           7043 non-null   int64
#  35  monthly_charges.1           7043 non-null   float64
#  36  total_charges.1             7043 non-null   object
#  37  signup_date                 7043 non-null   object
# dtypes: float64(2), int64(8), object(28)
# memory usage: 2.0+ MB

# %%
telco_df.describe(include='object').T
# Out:
#                       count unique                  top  freq
# customer_id            7043   7043           0002-ORFBO     1
# gender                 7043      2                 Male  3555
# partner                7043      2                   No  3641
# dependents             7043      2                   No  4933
# phone_service          7043      2                  Yes  6361
# multiple_lines         7043      3                   No  3390
# online_security        7043      3                   No  3498
# online_backup          7043      3                   No  3088
# device_protection      7043      3                   No  3095
# tech_support           7043      3                   No  3473
# streaming_tv           7043      3                   No  2810
# streaming_movies       7043      3                   No  2785
# paperless_billing      7043      2                  Yes  4171
# total_charges          7043   6531                         11
# churn                  7043      2                   No  5174
# contract_type          7043      3       Month-to-month  3875
# internet_service_type  7043      3          Fiber optic  3096
# phone_service.1        7043      2                  Yes  6361
# multiple_lines.1       7043      3                   No  3390
# online_security.1      7043      3                   No  3498
# online_backup.1        7043      3                   No  3088
# device_protection.1    7043      3                   No  3095
# tech_support.1         7043      3                   No  3473
# streaming_tv.1         7043      3                   No  2810
# streaming_movies.1     7043      3                   No  2785
# paperless_billing.1    7043      2                  Yes  4171
# total_charges.1        7043   6531                         11
# signup_date            7043     73  2021-12-21 18:07:34   613

# %%
telco_df.churn
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: churn, Length: 7043, dtype: object

# %%
def initial_data(data):
    telco_df=acquire.get_telco_data()
    print('this data frame has',telco_df.shape[0],'rows and', telco_df.shape[1],'columns')
    print('                        ')
    print(telco_df.info())
    print('                        ')
    print(telco_df.describe())
    print('                        ')
    print(telco_df.describe(include='object').T)
    print('                        ')
    print(telco_df.columns)
    print('ended of initial report')
    print('                        ')

# %%
initial_data(telco_df)
# Out:
# this data frame has 7043 rows and 38 columns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 7043 non-null   object
#  1   internet_service_type_id    7043 non-null   int64
#  2   contract_type_id            7043 non-null   int64
#  3   gender                      7043 non-null   object
#  4   senior_citizen              7043 non-null   int64
#  5   partner                     7043 non-null   object
#  6   dependents                  7043 non-null   object
#  7   tenure                      7043 non-null   int64
#  8   phone_service               7043 non-null   object
#  9   multiple_lines              7043 non-null   object
#  10  online_security             7043 non-null   object
#  11  online_backup               7043 non-null   object
#  12  device_protection           7043 non-null   object
#  13  tech_support                7043 non-null   object
#  14  streaming_tv                7043 non-null   object
#  15  streaming_movies            7043 non-null   object
#  16  paperless_billing           7043 non-null   object
#  17  payment_type_id             7043 non-null   int64
#  18  monthly_charges             7043 non-null   float64
#  19  total_charges               7043 non-null   object
#  20  churn                       7043 non-null   object
#  21  contract_type               7043 non-null   object
#  22  internet_service_type       7043 non-null   object
#  23  phone_service.1             7043 non-null   object
#  24  multiple_lines.1            7043 non-null   object
#  25  internet_service_type_id.1  7043 non-null   int64
#  26  online_security.1           7043 non-null   object
#  27  online_backup.1             7043 non-null   object
#  28  device_protection.1         7043 non-null   object
#  29  tech_support.1              7043 non-null   object
#  30  streaming_tv.1              7043 non-null   object
#  31  streaming_movies.1          7043 non-null   object
#  32  contract_type_id.1          7043 non-null   int64
#  33  paperless_billing.1         7043 non-null   object
#  34  payment_type_id.1           7043 non-null   int64
#  35  monthly_charges.1           7043 non-null   float64
#  36  total_charges.1             7043 non-null   object
#  37  signup_date                 7043 non-null   object
# dtypes: float64(2), int64(8), object(28)
# memory usage: 2.0+ MB
# None
#
#        internet_service_type_id  contract_type_id  senior_citizen  \
# count               7043.000000       7043.000000     7043.000000
# mean                   1.872923          1.690473        0.162147
# std                    0.737796          0.833755        0.368612
# min                    1.000000          1.000000        0.000000
# 25%                    1.000000          1.000000        0.000000
# 50%                    2.000000          1.000000        0.000000
# 75%                    2.000000          2.000000        0.000000
# max                    3.000000          3.000000        1.000000
#
#             tenure  payment_type_id  monthly_charges  \
# count  7043.000000      7043.000000      7043.000000
# mean     32.371149         2.315633        64.761692
# std      24.559481         1.148907        30.090047
# min       0.000000         1.000000        18.250000
# 25%       9.000000         1.000000        35.500000
# 50%      29.000000         2.000000        70.350000
# 75%      55.000000         3.000000        89.850000
# max      72.000000         4.000000       118.750000
#
#        internet_service_type_id.1  contract_type_id.1  payment_type_id.1  \
# count                 7043.000000         7043.000000        7043.000000
# mean                     1.872923            1.690473           2.315633
# std                      0.737796            0.833755           1.148907
# min                      1.000000            1.000000           1.000000
# 25%                      1.000000            1.000000           1.000000
# 50%                      2.000000            1.000000           2.000000
# 75%                      2.000000            2.000000           3.000000
# max                      3.000000            3.000000           4.000000
#
#        monthly_charges.1
# count        7043.000000
# mean           64.761692
# std            30.090047
# min            18.250000
# 25%            35.500000
# 50%            70.350000
# 75%            89.850000
# max           118.750000
#
#                       count unique                  top  freq
# customer_id            7043   7043           0002-ORFBO     1
# gender                 7043      2                 Male  3555
# partner                7043      2                   No  3641
# dependents             7043      2                   No  4933
# phone_service          7043      2                  Yes  6361
# multiple_lines         7043      3                   No  3390
# online_security        7043      3                   No  3498
# online_backup          7043      3                   No  3088
# device_protection      7043      3                   No  3095
# tech_support           7043      3                   No  3473
# streaming_tv           7043      3                   No  2810
# streaming_movies       7043      3                   No  2785
# paperless_billing      7043      2                  Yes  4171
# total_charges          7043   6531                         11
# churn                  7043      2                   No  5174
# contract_type          7043      3       Month-to-month  3875
# internet_service_type  7043      3          Fiber optic  3096
# phone_service.1        7043      2                  Yes  6361
# multiple_lines.1       7043      3                   No  3390
# online_security.1      7043      3                   No  3498
# online_backup.1        7043      3                   No  3088
# device_protection.1    7043      3                   No  3095
# tech_support.1         7043      3                   No  3473
# streaming_tv.1         7043      3                   No  2810
# streaming_movies.1     7043      3                   No  2785
# paperless_billing.1    7043      2                  Yes  4171
# total_charges.1        7043   6531                         11
# signup_date            7043     73  2021-12-21 18:07:34   613
#
# Index(['customer_id', 'internet_service_type_id', 'contract_type_id', 'gender',
#        'senior_citizen', 'partner', 'dependents', 'tenure', 'phone_service',
#        'multiple_lines', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'paperless_billing', 'payment_type_id', 'monthly_charges',
#        'total_charges', 'churn', 'contract_type', 'internet_service_type',
#        'phone_service.1', 'multiple_lines.1', 'internet_service_type_id.1',
#        'online_security.1', 'online_backup.1', 'device_protection.1',
#        'tech_support.1', 'streaming_tv.1', 'streaming_movies.1',
#        'contract_type_id.1', 'paperless_billing.1', 'payment_type_id.1',
#        'monthly_charges.1', 'total_charges.1', 'signup_date'],
#       dtype='object')
# ended of initial report

# %% [markdown]
# # Prepare Data

# %%
prep_telco=prepare.prep_telco(telco_df)
prep_telco
# Out:
#      customer_id  senior_citizen  tenure  monthly_charges  total_charges  \
# 0     0002-ORFBO               0       9            65.60         593.30
# 1     0003-MKNFE               0       9            59.90         542.40
# 2     0004-TLHLJ               0       4            73.90         280.85
# 3     0011-IGKFF               1      13            98.00        1237.85
# 4     0013-EXCHZ               1       3            83.90         267.40
# ...          ...             ...     ...              ...            ...
# 7038  9282-IZGQK               0       1            85.00          85.00
# 7039  9462-MJUAW               0       4            50.40         206.60
# 7040  9705-ZJBCG               0      13            54.15         701.05
# 7041  9777-IQHWP               0      64            93.40        5822.30
# 7042  9809-IMGCQ               1      22            96.70        2082.95
#
#        contract_type phone_service.1 multiple_lines.1  \
# 0           One year             Yes               No
# 1     Month-to-month             Yes              Yes
# 2     Month-to-month             Yes               No
# 3     Month-to-month             Yes               No
# 4     Month-to-month             Yes               No
# ...              ...             ...              ...
# 7038  Month-to-month             Yes              Yes
# 7039  Month-to-month             Yes              Yes
# 7040        One year             Yes               No
# 7041        Two year             Yes              Yes
# 7042  Month-to-month             Yes              Yes
#
#       internet_service_type_id.1 online_security.1  ... tech_support_Yes  \
# 0                              1                No  ...                1
# 1                              1                No  ...                0
# 2                              2                No  ...                0
# 3                              2                No  ...                0
# 4                              2                No  ...                1
# ...                          ...               ...  ...              ...
# 7038                           2                No  ...                0
# 7039                           1                No  ...                0
# 7040                           1               Yes  ...                1
# 7041                           2               Yes  ...                0
# 7042                           2                No  ...                0
#
#      streaming_tv_No internet service streaming_tv_Yes  \
# 0                                   0                1
# 1                                   0                0
# 2                                   0                0
# 3                                   0                1
# 4                                   0                1
# ...                               ...              ...
# 7038                                0                0
# 7039                                0                0
# 7040                                0                0
# 7041                                0                0
# 7042                                0                1
#
#      streaming_movies_No internet service streaming_movies_Yes  \
# 0                                       0                    0
# 1                                       0                    1
# 2                                       0                    0
# 3                                       0                    1
# 4                                       0                    0
# ...                                   ...                  ...
# 7038                                    0                    1
# 7039                                    0                    0
# 7040                                    0                    0
# 7041                                    0                    1
# 7042                                    0                    1
#
#       paperless_billing_Yes churn_Yes  internet_service_type_Fiber optic  \
# 0                         1         0                                  0
# 1                         0         0                                  0
# 2                         1         1                                  1
# 3                         1         1                                  1
# 4                         1         1                                  1
# ...                     ...       ...                                ...
# 7038                      1         1                                  1
# 7039                      0         1                                  0
# 7040                      0         0                                  0
# 7041                      0         0                                  1
# 7042                      1         1                                  1
#
#       internet_service_type_None gender_Male
# 0                              0           0
# 1                              0           1
# 2                              0           1
# 3                              0           1
# 4                              0           0
# ...                          ...         ...
# 7038                           0           0
# 7039                           0           1
# 7040                           0           0
# 7041                           0           1
# 7042                           0           1
#
# [7043 rows x 43 columns]

# %%
telco_train,telco_validate,telco_test=prepare.split_telco(prep_telco)
telco_train
# Out:
#      customer_id  senior_citizen  tenure  monthly_charges  total_charges  \
# 440   0643-OKLRP               1      47            80.35        3825.85
# 67    0112-QWPNC               0      49            84.35        4059.35
# 600   0877-SDMBN               0      54           103.95        5639.05
# 4883  5799-JRCZO               0      63            19.50        1215.10
# 1258  6837-BJYDQ               0       3            19.60          61.35
# ...          ...             ...     ...              ...            ...
# 1794  6296-DDOOR               0      19            58.20        1045.25
# 817   7629-WFGLW               1      56            95.65        5471.75
# 901   7929-DMBCV               0      20            81.00        1683.70
# 1987  9917-KWRBE               0      41            78.35        3211.20
# 6958  1839-UMACK               0      42            25.05         949.85
#
#        contract_type phone_service.1 multiple_lines.1  \
# 440   Month-to-month             Yes              Yes
# 67          One year             Yes              Yes
# 600         One year             Yes              Yes
# 4883        Two year             Yes               No
# 1258        One year             Yes               No
# ...              ...             ...              ...
# 1794        One year             Yes               No
# 817         One year             Yes              Yes
# 901   Month-to-month             Yes               No
# 1987        One year             Yes              Yes
# 6958        One year             Yes              Yes
#
#       internet_service_type_id.1    online_security.1  ... tech_support_Yes  \
# 440                            2                  Yes  ...                0
# 67                             1                  Yes  ...                1
# 600                            2                  Yes  ...                0
# 4883                           3  No internet service  ...                0
# 1258                           3  No internet service  ...                0
# ...                          ...                  ...  ...              ...
# 1794                           1                   No  ...                0
# 817                            2                  Yes  ...                1
# 901                            2                   No  ...                1
# 1987                           1                  Yes  ...                0
# 6958                           3  No internet service  ...                0
#
#      streaming_tv_No internet service streaming_tv_Yes  \
# 440                                 0                0
# 67                                  0                1
# 600                                 0                1
# 4883                                1                0
# 1258                                1                0
# ...                               ...              ...
# 1794                                0                1
# 817                                 0                0
# 901                                 0                0
# 1987                                0                1
# 6958                                1                0
#
#      streaming_movies_No internet service streaming_movies_Yes  \
# 440                                     0                    0
# 67                                      0                    1
# 600                                     0                    1
# 4883                                    1                    0
# 1258                                    1                    0
# ...                                   ...                  ...
# 1794                                    0                    0
# 817                                     0                    0
# 901                                     0                    0
# 1987                                    0                    0
# 6958                                    1                    0
#
#       paperless_billing_Yes churn_Yes  internet_service_type_Fiber optic  \
# 440                       0         1                                  1
# 67                        0         1                                  0
# 600                       1         1                                  1
# 4883                      0         0                                  0
# 1258                      0         0                                  0
# ...                     ...       ...                                ...
# 1794                      0         0                                  0
# 817                       0         0                                  1
# 901                       1         0                                  1
# 1987                      1         0                                  0
# 6958                      0         0                                  0
#
#       internet_service_type_None gender_Male
# 440                            0           0
# 67                             0           1
# 600                            0           0
# 4883                           1           0
# 1258                           1           1
# ...                          ...         ...
# 1794                           0           0
# 817                            0           0
# 901                            0           0
# 1987                           0           0
# 6958                           1           1
#
# [4225 rows x 43 columns]

# %%
telco_train.drop(columns=['internet_service_type_id.1','payment_type_id.1','contract_type_id.1'],inplace=True)
telco_validate.drop(columns=['internet_service_type_id.1','payment_type_id.1','contract_type_id.1'],inplace=True)
telco_test.drop(columns=['internet_service_type_id.1','payment_type_id.1','contract_type_id.1'],inplace=True)

# %% [markdown]
# # Explore Data

# %%
telco_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4225 entries, 440 to 6958
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customer_id                            4225 non-null   object
#  1   senior_citizen                         4225 non-null   int64
#  2   tenure                                 4225 non-null   int64
#  3   monthly_charges                        4225 non-null   float64
#  4   total_charges                          4225 non-null   float64
#  5   contract_type                          4225 non-null   object
#  6   phone_service.1                        4225 non-null   object
#  7   multiple_lines.1                       4225 non-null   object
#  8   online_security.1                      4225 non-null   object
#  9   online_backup.1                        4225 non-null   object
#  10  device_protection.1                    4225 non-null   object
#  11  tech_support.1                         4225 non-null   object
#  12  streaming_tv.1                         4225 non-null   object
#  13  streaming_movies.1                     4225 non-null   object
#  14  paperless_billing.1                    4225 non-null   object
#  15  monthly_charges.1                      4225 non-null   float64
#  16  total_charges.1                        4225 non-null   object
#  17  signup_date                            4225 non-null   object
#  18  partner_Yes                            4225 non-null   uint8
#  19  dependents_Yes                         4225 non-null   uint8
#  20  phone_service_Yes                      4225 non-null   uint8
#  21  multiple_lines_No phone service        4225 non-null   uint8
#  22  multiple_lines_Yes                     4225 non-null   uint8
#  23  online_security_No internet service    4225 non-null   uint8
#  24  online_security_Yes                    4225 non-null   uint8
#  25  online_backup_No internet service      4225 non-null   uint8
#  26  online_backup_Yes                      4225 non-null   uint8
#  27  device_protection_No internet service  4225 non-null   uint8
#  28  device_protection_Yes                  4225 non-null   uint8
#  29  tech_support_No internet service       4225 non-null   uint8
#  30  tech_support_Yes                       4225 non-null   uint8
#  31  streaming_tv_No internet service       4225 non-null   uint8
#  32  streaming_tv_Yes                       4225 non-null   uint8
#  33  streaming_movies_No internet service   4225 non-null   uint8
#  34  streaming_movies_Yes                   4225 non-null   uint8
#  35  paperless_billing_Yes                  4225 non-null   uint8
#  36  churn_Yes                              4225 non-null   uint8
#  37  internet_service_type_Fiber optic      4225 non-null   uint8
#  38  internet_service_type_None             4225 non-null   uint8
#  39  gender_Male                            4225 non-null   uint8
# dtypes: float64(3), int64(2), object(13), uint8(22)
# memory usage: 717.9+ KB

# %%
telco_train['month']=(telco_train.total_charges/telco_train.monthly_charges)
telco_validate['month']=(telco_train.total_charges/telco_train.monthly_charges)
telco_test['month']=(telco_train.total_charges/telco_train.monthly_charges)

# %%
telco_train.month.value_counts()
# Out:
# 1.000000     369
# 0.000000      10
# 47.614810      1
# 10.542056      1
# 48.987976      1
#             ...
# 62.241049      1
# 8.218795       1
# 66.251527      1
# 72.676393      1
# 37.918164      1
# Name: month, Length: 3848, dtype: int64

# %%
telco_train.month.value_counts().nunique()
# Out:
# 3

# %%
telco_train.columns
# Out:
# Index(['customer_id', 'senior_citizen', 'tenure', 'monthly_charges',
#        'total_charges', 'contract_type', 'phone_service.1', 'multiple_lines.1',
#        'online_security.1', 'online_backup.1', 'device_protection.1',
#        'tech_support.1', 'streaming_tv.1', 'streaming_movies.1',
#        'paperless_billing.1', 'monthly_charges.1', 'total_charges.1',
#        'signup_date', 'partner_Yes', 'dependents_Yes', 'phone_service_Yes',
#        'multiple_lines_No phone service', 'multiple_lines_Yes',
#        'online_security_No internet service', 'online_security_Yes',
#        'online_backup_No internet service', 'online_backup_Yes',
#        'device_protection_No internet service', 'device_protection_Yes',
#        'tech_support_No internet service', 'tech_support_Yes',
#        'streaming_tv_No internet service', 'streaming_tv_Yes',
#        'streaming_movies_No internet service', 'streaming_movies_Yes',
#        'paperless_billing_Yes', 'churn_Yes',
#        'internet_service_type_Fiber optic', 'internet_service_type_None',
#        'gender_Male', 'month', 'signup_month'],
#       dtype='object')

# %%
telco_train.contract_type
# Out:
# 440     Month-to-month
# 67            One year
# 600           One year
# 4883          Two year
# 1258          One year
#              ...
# 1794          One year
# 817           One year
# 901     Month-to-month
# 1987          One year
# 6958          One year
# Name: contract_type, Length: 4225, dtype: object

# %%
telco_train[telco_train.month==1].describe().T
# Out:
#                                        count       mean        std    min  \
# senior_citizen                         369.0   0.130081   0.336850   0.00
# tenure                                 369.0   1.000000   0.000000   1.00
# monthly_charges                        369.0  50.663686  24.890105  18.85
# total_charges                          369.0  50.663686  24.890105  18.85
# monthly_charges.1                      369.0  50.663686  24.890105  18.85
# partner_Yes                            369.0   0.170732   0.376785   0.00
# dependents_Yes                         369.0   0.184282   0.388240   0.00
# phone_service_Yes                      369.0   0.905149   0.293407   0.00
# multiple_lines_No phone service        369.0   0.094851   0.293407   0.00
# multiple_lines_Yes                     369.0   0.135501   0.342723   0.00
# online_security_No internet service    369.0   0.273713   0.446469   0.00
# online_security_Yes                    369.0   0.075881   0.265167   0.00
# online_backup_No internet service      369.0   0.273713   0.446469   0.00
# online_backup_Yes                      369.0   0.089431   0.285752   0.00
# device_protection_No internet service  369.0   0.273713   0.446469   0.00
# device_protection_Yes                  369.0   0.073171   0.260770   0.00
# tech_support_No internet service       369.0   0.273713   0.446469   0.00
# tech_support_Yes                       369.0   0.067751   0.251659   0.00
# streaming_tv_No internet service       369.0   0.273713   0.446469   0.00
# streaming_tv_Yes                       369.0   0.154472   0.361891   0.00
# streaming_movies_No internet service   369.0   0.273713   0.446469   0.00
# streaming_movies_Yes                   369.0   0.132791   0.339810   0.00
# paperless_billing_Yes                  369.0   0.590786   0.492356   0.00
# churn_Yes                              369.0   0.601626   0.490228   0.00
# internet_service_type_Fiber optic      369.0   0.373984   0.484516   0.00
# internet_service_type_None             369.0   0.273713   0.446469   0.00
# gender_Male                            369.0   0.528455   0.499867   0.00
# month                                  369.0   1.000000   0.000000   1.00
# signup_month                           369.0  12.000000   0.000000  12.00
#
#                                         25%   50%   75%     max
# senior_citizen                          0.0   0.0   0.0    1.00
# tenure                                  1.0   1.0   1.0    1.00
# monthly_charges                        20.9  50.1  74.1  102.45
# total_charges                          20.9  50.1  74.1  102.45
# monthly_charges.1                      20.9  50.1  74.1  102.45
# partner_Yes                             0.0   0.0   0.0    1.00
# dependents_Yes                          0.0   0.0   0.0    1.00
# phone_service_Yes                       1.0   1.0   1.0    1.00
# multiple_lines_No phone service         0.0   0.0   0.0    1.00
# multiple_lines_Yes                      0.0   0.0   0.0    1.00
# online_security_No internet service     0.0   0.0   1.0    1.00
# online_security_Yes                     0.0   0.0   0.0    1.00
# online_backup_No internet service       0.0   0.0   1.0    1.00
# online_backup_Yes                       0.0   0.0   0.0    1.00
# device_protection_No internet service   0.0   0.0   1.0    1.00
# device_protection_Yes                   0.0   0.0   0.0    1.00
# tech_support_No internet service        0.0   0.0   1.0    1.00
# tech_support_Yes                        0.0   0.0   0.0    1.00
# streaming_tv_No internet service        0.0   0.0   1.0    1.00
# streaming_tv_Yes                        0.0   0.0   0.0    1.00
# streaming_movies_No internet service    0.0   0.0   1.0    1.00
# streaming_movies_Yes                    0.0   0.0   0.0    1.00
# paperless_billing_Yes                   0.0   1.0   1.0    1.00
# churn_Yes                               0.0   1.0   1.0    1.00
# internet_service_type_Fiber optic       0.0   0.0   1.0    1.00
# internet_service_type_None              0.0   0.0   1.0    1.00
# gender_Male                             0.0   1.0   1.0    1.00
# month                                   1.0   1.0   1.0    1.00
# signup_month                           12.0  12.0  12.0   12.00

# %%
telco_train[telco_train.month>1].describe().T
# Out:
#                                         count         mean          std  \
# senior_citizen                         3846.0     0.165627     0.371793
# tenure                                 3846.0    35.283411    23.528402
# monthly_charges                        3846.0    65.739288    30.297604
# total_charges                          3846.0  2461.375000  2238.102575
# monthly_charges.1                      3846.0    65.739288    30.297604
# partner_Yes                            3846.0     0.507800     0.500004
# dependents_Yes                         3846.0     0.299012     0.457885
# phone_service_Yes                      3846.0     0.900936     0.298787
# multiple_lines_No phone service        3846.0     0.099064     0.298787
# multiple_lines_Yes                     3846.0     0.444098     0.496930
# online_security_No internet service    3846.0     0.214769     0.410715
# online_security_Yes                    3846.0     0.300312     0.458453
# online_backup_No internet service      3846.0     0.214769     0.410715
# online_backup_Yes                      3846.0     0.364015     0.481215
# device_protection_No internet service  3846.0     0.214769     0.410715
# device_protection_Yes                  3846.0     0.363235     0.480994
# tech_support_No internet service       3846.0     0.214769     0.410715
# tech_support_Yes                       3846.0     0.312012     0.463375
# streaming_tv_No internet service       3846.0     0.214769     0.410715
# streaming_tv_Yes                       3846.0     0.407436     0.491421
# streaming_movies_No internet service   3846.0     0.214769     0.410715
# streaming_movies_Yes                   3846.0     0.407436     0.491421
# paperless_billing_Yes                  3846.0     0.593604     0.491224
# churn_Yes                              3846.0     0.226989     0.418940
# internet_service_type_Fiber optic      3846.0     0.442278     0.496722
# internet_service_type_None             3846.0     0.214769     0.410715
# gender_Male                            3846.0     0.502340     0.500060
# month                                  3846.0    35.286154    23.569700
# signup_month                           3846.0     6.303172     3.511545
#
#                                              min         25%          50%  \
# senior_citizen                          0.000000    0.000000     0.000000
# tenure                                  2.000000   13.000000    34.000000
# monthly_charges                        18.400000   36.062500    71.500000
# total_charges                          31.200000  599.475000  1627.800000
# monthly_charges.1                      18.400000   36.062500    71.500000
# partner_Yes                             0.000000    0.000000     1.000000
# dependents_Yes                          0.000000    0.000000     0.000000
# phone_service_Yes                       0.000000    1.000000     1.000000
# multiple_lines_No phone service         0.000000    0.000000     0.000000
# multiple_lines_Yes                      0.000000    0.000000     0.000000
# online_security_No internet service     0.000000    0.000000     0.000000
# online_security_Yes                     0.000000    0.000000     0.000000
# online_backup_No internet service       0.000000    0.000000     0.000000
# online_backup_Yes                       0.000000    0.000000     0.000000
# device_protection_No internet service   0.000000    0.000000     0.000000
# device_protection_Yes                   0.000000    0.000000     0.000000
# tech_support_No internet service        0.000000    0.000000     0.000000
# tech_support_Yes                        0.000000    0.000000     0.000000
# streaming_tv_No internet service        0.000000    0.000000     0.000000
# streaming_tv_Yes                        0.000000    0.000000     0.000000
# streaming_movies_No internet service    0.000000    0.000000     0.000000
# streaming_movies_Yes                    0.000000    0.000000     0.000000
# paperless_billing_Yes                   0.000000    0.000000     1.000000
# churn_Yes                               0.000000    0.000000     0.000000
# internet_service_type_Fiber optic       0.000000    0.000000     0.000000
# internet_service_type_None              0.000000    0.000000     0.000000
# gender_Male                             0.000000    0.000000     1.000000
# month                                   1.497951   12.927532    33.326713
# signup_month                            1.000000    3.000000     6.000000
#
#                                                75%          max
# senior_citizen                            0.000000     1.000000
# tenure                                   57.000000    72.000000
# monthly_charges                          90.437500   118.750000
# total_charges                          4007.650000  8684.800000
# monthly_charges.1                        90.437500   118.750000
# partner_Yes                               1.000000     1.000000
# dependents_Yes                            1.000000     1.000000
# phone_service_Yes                         1.000000     1.000000
# multiple_lines_No phone service           0.000000     1.000000
# multiple_lines_Yes                        1.000000     1.000000
# online_security_No internet service       0.000000     1.000000
# online_security_Yes                       1.000000     1.000000
# online_backup_No internet service         0.000000     1.000000
# online_backup_Yes                         1.000000     1.000000
# device_protection_No internet service     0.000000     1.000000
# device_protection_Yes                     1.000000     1.000000
# tech_support_No internet service          0.000000     1.000000
# tech_support_Yes                          1.000000     1.000000
# streaming_tv_No internet service          0.000000     1.000000
# streaming_tv_Yes                          1.000000     1.000000
# streaming_movies_No internet service      0.000000     1.000000
# streaming_movies_Yes                      1.000000     1.000000
# paperless_billing_Yes                     1.000000     1.000000
# churn_Yes                                 0.000000     1.000000
# internet_service_type_Fiber optic         1.000000     1.000000
# internet_service_type_None                0.000000     1.000000
# gender_Male                               1.000000     1.000000
# month                                    57.029773    79.341772
# signup_month                              9.000000    12.000000

# %%
telco_train[telco_train.month>1].describe().T==telco_train[telco_train.month==1].describe().T
# Out:
#                                        count   mean    std    min    25%  \
# senior_citizen                         False  False  False   True   True
# tenure                                 False  False  False  False  False
# monthly_charges                        False  False  False  False  False
# total_charges                          False  False  False  False  False
# monthly_charges.1                      False  False  False  False  False
# partner_Yes                            False  False  False   True   True
# dependents_Yes                         False  False  False   True   True
# phone_service_Yes                      False  False  False   True   True
# multiple_lines_No phone service        False  False  False   True   True
# multiple_lines_Yes                     False  False  False   True   True
# online_security_No internet service    False  False  False   True   True
# online_security_Yes                    False  False  False   True   True
# online_backup_No internet service      False  False  False   True   True
# online_backup_Yes                      False  False  False   True   True
# device_protection_No internet service  False  False  False   True   True
# device_protection_Yes                  False  False  False   True   True
# tech_support_No internet service       False  False  False   True   True
# tech_support_Yes                       False  False  False   True   True
# streaming_tv_No internet service       False  False  False   True   True
# streaming_tv_Yes                       False  False  False   True   True
# streaming_movies_No internet service   False  False  False   True   True
# streaming_movies_Yes                   False  False  False   True   True
# paperless_billing_Yes                  False  False  False   True   True
# churn_Yes                              False  False  False   True   True
# internet_service_type_Fiber optic      False  False  False   True   True
# internet_service_type_None             False  False  False   True   True
# gender_Male                            False  False  False   True   True
# month                                  False  False  False  False  False
#
#                                          50%    75%    max
# senior_citizen                          True   True   True
# tenure                                 False  False  False
# monthly_charges                        False  False  False
# total_charges                          False  False  False
# monthly_charges.1                      False  False  False
# partner_Yes                            False  False   True
# dependents_Yes                          True  False   True
# phone_service_Yes                       True   True   True
# multiple_lines_No phone service         True   True   True
# multiple_lines_Yes                      True  False   True
# online_security_No internet service     True  False   True
# online_security_Yes                     True  False   True
# online_backup_No internet service       True  False   True
# online_backup_Yes                       True  False   True
# device_protection_No internet service   True  False   True
# device_protection_Yes                   True  False   True
# tech_support_No internet service        True  False   True
# tech_support_Yes                        True  False   True
# streaming_tv_No internet service        True  False   True
# streaming_tv_Yes                        True  False   True
# streaming_movies_No internet service    True  False   True
# streaming_movies_Yes                    True  False   True
# paperless_billing_Yes                   True   True   True
# churn_Yes                              False  False   True
# internet_service_type_Fiber optic       True   True   True
# internet_service_type_None              True  False   True
# gender_Male                             True   True   True
# month                                  False  False  False

# %%
telco_train[telco_train.month==1].churn_Yes.value_counts()
# Out:
# 1    222
# 0    147
# Name: churn_Yes, dtype: int64

# %%
telco_train[telco_train.churn_Yes==1].describe().T
# Out:
#                                         count         mean          std   min  \
# senior_citizen                         1095.0     0.255708     0.436458   0.0
# tenure                                 1095.0    17.214612    19.137828   1.0
# monthly_charges                        1095.0    74.669224    24.455831  19.1
# total_charges                          1095.0  1481.756986  1866.510293  19.1
# monthly_charges.1                      1095.0    74.669224    24.455831  19.1
# partner_Yes                            1095.0     0.350685     0.477403   0.0
# dependents_Yes                         1095.0     0.165297     0.371618   0.0
# phone_service_Yes                      1095.0     0.905023     0.293317   0.0
# multiple_lines_No phone service        1095.0     0.094977     0.293317   0.0
# multiple_lines_Yes                     1095.0     0.453881     0.498096   0.0
# online_security_No internet service    1095.0     0.052968     0.224072   0.0
# online_security_Yes                    1095.0     0.154338     0.361437   0.0
# online_backup_No internet service      1095.0     0.052968     0.224072   0.0
# online_backup_Yes                      1095.0     0.264840     0.441450   0.0
# device_protection_No internet service  1095.0     0.052968     0.224072   0.0
# device_protection_Yes                  1095.0     0.281279     0.449829   0.0
# tech_support_No internet service       1095.0     0.052968     0.224072   0.0
# tech_support_Yes                       1095.0     0.161644     0.368292   0.0
# streaming_tv_No internet service       1095.0     0.052968     0.224072   0.0
# streaming_tv_Yes                       1095.0     0.448402     0.497558   0.0
# streaming_movies_No internet service   1095.0     0.052968     0.224072   0.0
# streaming_movies_Yes                   1095.0     0.432877     0.495700   0.0
# paperless_billing_Yes                  1095.0     0.760731     0.426832   0.0
# churn_Yes                              1095.0     1.000000     0.000000   1.0
# internet_service_type_Fiber optic      1095.0     0.701370     0.457866   0.0
# internet_service_type_None             1095.0     0.052968     0.224072   0.0
# gender_Male                            1095.0     0.492237     0.500168   0.0
# month                                  1095.0    17.214360    19.177194   1.0
#
#                                              25%         50%          75%  \
# senior_citizen                           0.00000    0.000000     1.000000
# tenure                                   2.00000    9.000000    28.000000
# monthly_charges                         58.80000   79.650000    94.225000
# total_charges                          131.05000  633.400000  2259.125000
# monthly_charges.1                       58.80000   79.650000    94.225000
# partner_Yes                              0.00000    0.000000     1.000000
# dependents_Yes                           0.00000    0.000000     0.000000
# phone_service_Yes                        1.00000    1.000000     1.000000
# multiple_lines_No phone service          0.00000    0.000000     0.000000
# multiple_lines_Yes                       0.00000    0.000000     1.000000
# online_security_No internet service      0.00000    0.000000     0.000000
# online_security_Yes                      0.00000    0.000000     0.000000
# online_backup_No internet service        0.00000    0.000000     0.000000
# online_backup_Yes                        0.00000    0.000000     1.000000
# device_protection_No internet service    0.00000    0.000000     0.000000
# device_protection_Yes                    0.00000    0.000000     1.000000
# tech_support_No internet service         0.00000    0.000000     0.000000
# tech_support_Yes                         0.00000    0.000000     0.000000
# streaming_tv_No internet service         0.00000    0.000000     0.000000
# streaming_tv_Yes                         0.00000    0.000000     1.000000
# streaming_movies_No internet service     0.00000    0.000000     0.000000
# streaming_movies_Yes                     0.00000    0.000000     1.000000
# paperless_billing_Yes                    1.00000    1.000000     1.000000
# churn_Yes                                1.00000    1.000000     1.000000
# internet_service_type_Fiber optic        0.00000    1.000000     1.000000
# internet_service_type_None               0.00000    0.000000     0.000000
# gender_Male                              0.00000    0.000000     1.000000
# month                                    2.06648    9.056829    27.929853
#
#                                                max
# senior_citizen                            1.000000
# tenure                                   72.000000
# monthly_charges                         118.350000
# total_charges                          8684.800000
# monthly_charges.1                       118.350000
# partner_Yes                               1.000000
# dependents_Yes                            1.000000
# phone_service_Yes                         1.000000
# multiple_lines_No phone service           1.000000
# multiple_lines_Yes                        1.000000
# online_security_No internet service       1.000000
# online_security_Yes                       1.000000
# online_backup_No internet service         1.000000
# online_backup_Yes                         1.000000
# device_protection_No internet service     1.000000
# device_protection_Yes                     1.000000
# tech_support_No internet service          1.000000
# tech_support_Yes                          1.000000
# streaming_tv_No internet service          1.000000
# streaming_tv_Yes                          1.000000
# streaming_movies_No internet service      1.000000
# streaming_movies_Yes                      1.000000
# paperless_billing_Yes                     1.000000
# churn_Yes                                 1.000000
# internet_service_type_Fiber optic         1.000000
# internet_service_type_None                1.000000
# gender_Male                               1.000000
# month                                    74.231579

# %%
len(telco_train[telco_train.month==1])/len(telco_train[telco_train.churn_Yes==1])
# Out:
# 0.336986301369863

# %%
telco_train[telco_train.churn_Yes==0].describe().T==telco_train[telco_train.churn_Yes==1].describe().T
# Out:
#                                        count   mean    std    min    25%  \
# senior_citizen                         False  False  False   True   True
# tenure                                 False  False  False  False  False
# monthly_charges                        False  False  False  False  False
# total_charges                          False  False  False  False  False
# monthly_charges.1                      False  False  False  False  False
# partner_Yes                            False  False  False   True   True
# dependents_Yes                         False  False  False   True   True
# phone_service_Yes                      False  False  False   True   True
# multiple_lines_No phone service        False  False  False   True   True
# multiple_lines_Yes                     False  False  False   True   True
# online_security_No internet service    False  False  False   True   True
# online_security_Yes                    False  False  False   True   True
# online_backup_No internet service      False  False  False   True   True
# online_backup_Yes                      False  False  False   True   True
# device_protection_No internet service  False  False  False   True   True
# device_protection_Yes                  False  False  False   True   True
# tech_support_No internet service       False  False  False   True   True
# tech_support_Yes                       False  False  False   True   True
# streaming_tv_No internet service       False  False  False   True   True
# streaming_tv_Yes                       False  False  False   True   True
# streaming_movies_No internet service   False  False  False   True   True
# streaming_movies_Yes                   False  False  False   True   True
# paperless_billing_Yes                  False  False  False   True  False
# churn_Yes                              False  False   True  False  False
# internet_service_type_Fiber optic      False  False  False   True   True
# internet_service_type_None             False  False  False   True   True
# gender_Male                            False  False  False   True   True
# month                                  False  False  False  False  False
#
#                                          50%    75%    max
# senior_citizen                          True  False   True
# tenure                                 False  False   True
# monthly_charges                        False  False  False
# total_charges                          False  False  False
# monthly_charges.1                      False  False  False
# partner_Yes                            False   True   True
# dependents_Yes                          True  False   True
# phone_service_Yes                       True   True   True
# multiple_lines_No phone service         True   True   True
# multiple_lines_Yes                      True   True   True
# online_security_No internet service     True  False   True
# online_security_Yes                     True  False   True
# online_backup_No internet service       True  False   True
# online_backup_Yes                       True   True   True
# device_protection_No internet service   True  False   True
# device_protection_Yes                   True   True   True
# tech_support_No internet service        True  False   True
# tech_support_Yes                        True  False   True
# streaming_tv_No internet service        True  False   True
# streaming_tv_Yes                        True   True   True
# streaming_movies_No internet service    True  False   True
# streaming_movies_Yes                    True   True   True
# paperless_billing_Yes                   True   True   True
# churn_Yes                              False  False  False
# internet_service_type_Fiber optic      False   True   True
# internet_service_type_None              True  False   True
# gender_Male                            False   True   True
# month                                  False  False  False

# %%
g=sns.JointGrid(data=telco_train, x="month", y="tenure", space=0, ratio=17,hue='churn_Yes')
g.plot_joint(sns.scatterplot, size=telco_train["churn_Yes"], sizes=(50, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
g=sns.JointGrid(data=telco_train, x="month", y="partner_Yes", space=0, ratio=17,hue='churn_Yes')
g.plot_joint(sns.scatterplot, size=telco_train["churn_Yes"], sizes=(50, 120),
             color="g", alpha=.6, legend=True)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
telco_train_m=telco_train[telco_train.month<=1]
telco_train_m[telco_train_m.churn_Yes==1].describe().T
# Out:
#                                        count       mean        std   min  \
# senior_citizen                         222.0   0.198198   0.399543   0.0
# tenure                                 222.0   1.000000   0.000000   1.0
# monthly_charges                        222.0  58.196396  24.142377  19.1
# total_charges                          222.0  58.196396  24.142377  19.1
# monthly_charges.1                      222.0  58.196396  24.142377  19.1
# partner_Yes                            222.0   0.202703   0.402921   0.0
# dependents_Yes                         222.0   0.162162   0.369432   0.0
# phone_service_Yes                      222.0   0.882883   0.322286   0.0
# multiple_lines_No phone service        222.0   0.117117   0.322286   0.0
# multiple_lines_Yes                     222.0   0.166667   0.373520   0.0
# online_security_No internet service    222.0   0.153153   0.360949   0.0
# online_security_Yes                    222.0   0.063063   0.243626   0.0
# online_backup_No internet service      222.0   0.153153   0.360949   0.0
# online_backup_Yes                      222.0   0.094595   0.293316   0.0
# device_protection_No internet service  222.0   0.153153   0.360949   0.0
# device_protection_Yes                  222.0   0.099099   0.299470   0.0
# tech_support_No internet service       222.0   0.153153   0.360949   0.0
# tech_support_Yes                       222.0   0.040541   0.197669   0.0
# streaming_tv_No internet service       222.0   0.153153   0.360949   0.0
# streaming_tv_Yes                       222.0   0.216216   0.412594   0.0
# streaming_movies_No internet service   222.0   0.153153   0.360949   0.0
# streaming_movies_Yes                   222.0   0.166667   0.373520   0.0
# paperless_billing_Yes                  222.0   0.702703   0.458101   0.0
# churn_Yes                              222.0   1.000000   0.000000   1.0
# internet_service_type_Fiber optic      222.0   0.527027   0.500397   0.0
# internet_service_type_None             222.0   0.153153   0.360949   0.0
# gender_Male                            222.0   0.472973   0.500397   0.0
# month                                  222.0   1.000000   0.000000   1.0
#
#                                            25%   50%    75%     max
# senior_citizen                          0.0000   0.0   0.00    1.00
# tenure                                  1.0000   1.0   1.00    1.00
# monthly_charges                        39.7625  69.3  78.35  102.45
# total_charges                          39.7625  69.3  78.35  102.45
# monthly_charges.1                      39.7625  69.3  78.35  102.45
# partner_Yes                             0.0000   0.0   0.00    1.00
# dependents_Yes                          0.0000   0.0   0.00    1.00
# phone_service_Yes                       1.0000   1.0   1.00    1.00
# multiple_lines_No phone service         0.0000   0.0   0.00    1.00
# multiple_lines_Yes                      0.0000   0.0   0.00    1.00
# online_security_No internet service     0.0000   0.0   0.00    1.00
# online_security_Yes                     0.0000   0.0   0.00    1.00
# online_backup_No internet service       0.0000   0.0   0.00    1.00
# online_backup_Yes                       0.0000   0.0   0.00    1.00
# device_protection_No internet service   0.0000   0.0   0.00    1.00
# device_protection_Yes                   0.0000   0.0   0.00    1.00
# tech_support_No internet service        0.0000   0.0   0.00    1.00
# tech_support_Yes                        0.0000   0.0   0.00    1.00
# streaming_tv_No internet service        0.0000   0.0   0.00    1.00
# streaming_tv_Yes                        0.0000   0.0   0.00    1.00
# streaming_movies_No internet service    0.0000   0.0   0.00    1.00
# streaming_movies_Yes                    0.0000   0.0   0.00    1.00
# paperless_billing_Yes                   0.0000   1.0   1.00    1.00
# churn_Yes                               1.0000   1.0   1.00    1.00
# internet_service_type_Fiber optic       0.0000   1.0   1.00    1.00
# internet_service_type_None              0.0000   0.0   0.00    1.00
# gender_Male                             0.0000   0.0   1.00    1.00
# month                                   1.0000   1.0   1.00    1.00

# %%
telco_train_m[telco_train_m.churn_Yes==1].contract_type.value_counts()
# Out:
# Month-to-month    222
# Name: contract_type, dtype: int64

# %%
222/688
# Out:
# 0.3226744186046512

# %%
report_wdate.signup_date(telco_train)
# Out:
#      customer_id  senior_citizen  tenure  monthly_charges  total_charges  \
# 440   0643-OKLRP               1      47            80.35        3825.85
# 67    0112-QWPNC               0      49            84.35        4059.35
# 600   0877-SDMBN               0      54           103.95        5639.05
# 4883  5799-JRCZO               0      63            19.50        1215.10
# 1258  6837-BJYDQ               0       3            19.60          61.35
# ...          ...             ...     ...              ...            ...
# 1794  6296-DDOOR               0      19            58.20        1045.25
# 817   7629-WFGLW               1      56            95.65        5471.75
# 901   7929-DMBCV               0      20            81.00        1683.70
# 1987  9917-KWRBE               0      41            78.35        3211.20
# 6958  1839-UMACK               0      42            25.05         949.85
#
#        contract_type phone_service.1 multiple_lines.1    online_security.1  \
# 440   Month-to-month             Yes              Yes                  Yes
# 67          One year             Yes              Yes                  Yes
# 600         One year             Yes              Yes                  Yes
# 4883        Two year             Yes               No  No internet service
# 1258        One year             Yes               No  No internet service
# ...              ...             ...              ...                  ...
# 1794        One year             Yes               No                   No
# 817         One year             Yes              Yes                  Yes
# 901   Month-to-month             Yes               No                   No
# 1987        One year             Yes              Yes                  Yes
# 6958        One year             Yes              Yes  No internet service
#
#           online_backup.1  ... streaming_tv_Yes  \
# 440                    No  ...                0
# 67                     No  ...                1
# 600                    No  ...                1
# 4883  No internet service  ...                0
# 1258  No internet service  ...                0
# ...                   ...  ...              ...
# 1794                  Yes  ...                1
# 817                   Yes  ...                0
# 901                    No  ...                0
# 1987                  Yes  ...                1
# 6958  No internet service  ...                0
#
#      streaming_movies_No internet service streaming_movies_Yes  \
# 440                                     0                    0
# 67                                      0                    1
# 600                                     0                    1
# 4883                                    1                    0
# 1258                                    1                    0
# ...                                   ...                  ...
# 1794                                    0                    0
# 817                                     0                    0
# 901                                     0                    0
# 1987                                    0                    0
# 6958                                    1                    0
#
#      paperless_billing_Yes churn_Yes  internet_service_type_Fiber optic  \
# 440                      0         1                                  1
# 67                       0         1                                  0
# 600                      1         1                                  1
# 4883                     0         0                                  0
# 1258                     0         0                                  0
# ...                    ...       ...                                ...
# 1794                     0         0                                  0
# 817                      0         0                                  1
# 901                      1         0                                  1
# 1987                     1         0                                  0
# 6958                     0         0                                  0
#
#      internet_service_type_None gender_Male      month  signup_month
# 440                           0           0  47.614810             2
# 67                            0           1  48.125074            12
# 600                           0           0  54.247715             7
# 4883                          1           0  62.312821            10
# 1258                          1           1   3.130102            10
# ...                         ...         ...        ...           ...
# 1794                          0           0  17.959622             6
# 817                           0           0  57.205959             5
# 901                           0           0  20.786420             5
# 1987                          0           0  40.985322             8
# 6958                          1           1  37.918164             7
#
# [4225 rows x 42 columns]

# %%
report_wdate.compareid(telco_train).nunique()
# Out:
# 1

# %%
sns.displot(
    data=telco_train,
    x="monthly_charges", hue="churn_Yes",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.violinplot(data=telco_train, x='online_security_Yes',y='churn_Yes',palette="light:g", inner="points", orient="h")
# Out:
# <AxesSubplot:xlabel='online_security_Yes', ylabel='churn_Yes'>

# %%
sns.displot(
    data=telco_train,
    x="tenure", hue="churn_Yes",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.displot(
    data=telco_train,
    x="month", hue="churn_Yes",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.violinplot(data=telco_train, x='signup_month',y='churn_Yes',palette="light:g", inner="points", orient="h")
# Out:
# <AxesSubplot:xlabel='signup_month', ylabel='churn_Yes'>

# %%
sns.lineplot(data=telco_train, x="signup_month", y="month",hue='churn_Yes')
# Out:
# <AxesSubplot:xlabel='signup_month', ylabel='month'>

# %%
sns.relplot(x="signup_month", y="contract_type", hue="churn_Yes",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=telco_train)

# %%
sns.relplot(x="month", y="contract_type", hue="churn_Yes",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=telco_train)

# %%
stats.mannwhitneyu(telco_train.month, telco_train.tenure)
# Out:
# MannwhitneyuResult(statistic=8924500.0, pvalue=0.9942196255449333)
